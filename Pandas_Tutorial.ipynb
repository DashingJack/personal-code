# %%
import pandas as pd

# %%
dt1 = pd.read_csv("/content/drive/MyDrive/pokemon.csv") #store data in dt1 object
dt1

# %%
dt1.shape #shows stucture of data

# %%
dt1.describe #shows whole data

# %%
dt1.dtypes #shows datatypes of all columns

# %%
dt1["japanese_name"].dtype #shows data type of given columna

# %%
dt1.head() #shows top 5 rows

# %%
dt1.tail() #shows last 5 rows

# %%
dt1.head(10) #shows top 10 rows of data

# %%
dt1.columns #shows names of all columns

# %%
dt1['japanese_name'] #shows data of given column

# %%
dt1[['name', 'japanese_name']] #shows values of given columns

# %%
pd.set_option('display.max_rows', None) #shows all rows of dt1
print(dt1)

# %% [markdown]
# iloc - integer position based

# %%
dt1.iloc[149] #shows data of row 149

# %%
dt1.iloc[:151] #shows rows 0 to 151

# %%
dt1.iloc[25,21] #shows values of index 25,21

# %%
dt1.iloc[100:200,18:23] #shows columns 18 to 23 and rows 100 to 200

# %%
dt1.loc[dt1.against_dragon == 2] #finds given value

# %%
dt1.sort_values('base_egg_steps', ascending=True) #sorts values
#or dt1.sort_values('base_egg_steps')

# %%
dt1['total'] = dt1.against_bug + dt1.against_normal #makes column
dt1

# %%
dt1 = dt1.drop(columns = 'total') #drops column
dt1

# %%
dt1.loc[dt1.abilities.str.contains('Blaze')]

# %%
new_dt1 = dt1.loc[(dt1.type1 == 'bug') & (dt1.type2 == 'fire')]
new_dt1

# %%
new_dt1.reset_index()
