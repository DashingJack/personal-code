# %% [markdown]
# #If... Else...

# %%
a = 5
if a in [1,2,3,4,5]:
  print('a is in list')
elif a > 5:
  print('a is greater than 5')
else:
  print('a is not in list')
# Out:
# a is in list

# %%
i = [1, 2, 3]
j = [1, 2, 3]
k = i

if i==j:
  print('i and j are equal')
if i is j:
  print('i and j are same')
else
  print('i and j are not same same')

if i is k:
  print('i and k are equal')
# Out:
#   File "<ipython-input-3-5e8dc05017a2>", line 9
#     else
#         ^
# SyntaxError: invalid syntax
